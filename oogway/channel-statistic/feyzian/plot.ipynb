# %%
import numpy as np
import matplotlib.pyplot as plt


x = [round(0.5+(0.05*num),2) for num in range(0, 40)]


y_gross_0 = [
20.92,
13.37,
24.83,
28.41,
41.85,
34.70,
27.55,
27.15,
20.05,
19.50,
25.35,
25.72,
18.82,
34.05,
36.30,
48.23,
48.23,
41.73,
41.56,
43.94,
37.54,
31.14,
39.13,
47.59,
41.39,
41.71,
35.56,
29.41,
23.26,
24.08,
26.34,
20.29,
31.65,
34.17,
45.9,
40.10,
34.30,
28.50,
22.70,
16.90,

]


y_loss_0 = [
-94.67,
-102.22,
-107.97,
-114.07,
-119.27,
-126.42,
-133.57,
-139.87,
-146.97,
-153.12,
-158.17,
-164.07,
-170.97,
-174.42,
-179.97,
-182.92,
-188.17,
-194.67,
-199.77,
-204.77,
-211.17,
-217.57,
-220.77,
-223.77,
-229.97,
-234.42,
-240.577,
-246.72,
-252.87,
-257.07,
-261.17,
-267.22,
-269.07,
-272.87,
-274.37,
-280.17,
-285.97,
-291.77,
-297.57,
-303.37,
]


y_profit_0 = [
 115.59,
 115.59,
 132.8,
 142.48,
 161.12,
 161.12,
 161.12,
 167.02,
 167.02,
 172.62,
 183.52,
 189.79,
 189.79,
 208.47,
 216.27,
 231.15,
 236.4,
 236.4,
 241.33,
 248.71,
 248.71,
 248.71,
 259.9,
 271.36,
 271.36,
 276.13,
 276.14,
 276.13,
 276.13,
 281.15,
 287.51,
 287.51,
 300.72,
 307.04,
 320.27,
 320.27,
 320.27,
 320.27,
 320.27,
 320.27]

# %%
yyy = [y_profit_0, y_loss_0, y_gross_0]
titles = ["profit", "loss", "gross"]


for i, y in enumerate(yyy):

    plt.scatter(x, y)

    max_value = np.max(y)
    max_index = np.argmax(y)
    max_x_value = x[max_index]

    min_value = np.min(y)
    min_index = np.argmin(y)
    min_x_value = x[min_index]

    plt.title(f"{titles[i]} chart")

    plt.scatter(max_x_value, max_value, color='green')
    plt.text(max_x_value, max_value, f'max = ({max_x_value}, {max_value:.2f})', color='green')

    plt.scatter(min_x_value, min_value, color='red')
    plt.text(min_x_value, min_value, f'min = ({min_x_value}, {min_value:.2f})', color='red')
    plt.show()

# %%
y_gross_1 = [
61.80,
53.70,
71.23,
63.23,
55.23,
47.23,
39.23,
31.23,
23.23,
28.15,
20.20,
12.25,
4.30,
22.89,
35.21,
39.62,
44.13,
36.43,
50.20,
42.60,
35.00,
27.4,
36.59,
29.04,
36.23,
36.91,
29.46,
22.01,
14.56,
7.11,
15.76,
8.365,
20.05,
27.71,
34.97,
 27.72,
20.47,
13.22,
5.97,
-1.27,
10.85,
]


y_loss_1 = [
-81,
-89.09,
-95.99,
-104,
-112,
-120,
-127.99,
-135.99,
-144,
-151.04,
-159,
-166.95,
-174.89,
-180.55,
-187.19,
-193,
-200.20,
-207.89,
-212.80,
-220.39,
-228,
-235.60,
-241.59,
-249.15,
-254.99,
-260.75,
-268.20,
-275.64,
-283.10,
-290.54,
-296,
-303.40,
-308.70,
-313.89,
-318.99,
-326.25,
-333.5,
-340.75,
-347.99,
-355.24,
-360.0,
]


y_profit_1 = [142.8,
 142.79,
 167.22,
 167.23,
 167.23,
 167.23,
 167.22,
 167.22,
 167.23,
 179.19,
 179.2,
 179.2,
 179.19,
 203.44,
 222.4,
 232.62,
 244.33,
 244.32,
 263.0,
 262.99,
 263.0,
 263.0,
 278.18,
 278.19,
 291.22,
 297.66,
 297.66,
 297.65,
 297.66,
 297.65,
 311.76,
 311.76,
 328.75,
 341.6,
 353.96,
 353.97,
 353.97,
 353.97,
 353.96,
 353.97,
 370.85]

# %%
x.append(2.5)
yyy = [y_profit_1, y_loss_1, y_gross_1]
titles = ["profit", "loss", "gross"]


for i, y in enumerate(yyy):

    plt.scatter(x, y)

    max_value = np.max(y)
    max_index = np.argmax(y)
    max_x_value = x[max_index]

    min_value = np.min(y)
    min_index = np.argmin(y)
    min_x_value = x[min_index]

    plt.title(f"{titles[i]} chart")

    plt.scatter(max_x_value, max_value, color='green')
    plt.text(max_x_value, max_value, f'max = ({max_x_value}, {max_value:.2f})', color='green')

    plt.scatter(min_x_value, min_value, color='red')
    plt.text(min_x_value, min_value, f'min = ({min_x_value}, {min_value:.2f})', color='red')
    plt.show()

# %%
y_profit_2 = [172.26,
 172.26,
 190.37,
 190.37,
 190.37,
 190.37,
 190.37,
 190.37,
 190.37,
 190.37,
 190.37,
 190.37,
 190.37,
 230.29,
 230.29,
 230.29,
 230.29,
 230.29,
 245.32,
 245.32,
 245.32,
 245.32,
 270.72,
 270.72,
 270.72,
 270.72,
 270.72,
 270.72,
 270.72,
 270.72,
 294.05,
 294.05,
 325.99,
 325.99,
 343.11,
 343.11,
 343.11,
 343.11,
 343.11,
 343.11,
 343.11]

y_loss_2 =[-82.0,
 -90.2,
 -97.8,
 -105.95,
 -114.1,
 -122.25,
 -130.4,
 -138.55,
 -146.7,
 -154.85,
 -163.0,
 -171.15,
 -179.3,
 -185.15,
 -193.2,
 -201.25,
 -209.3,
 -217.35,
 -224.0,
 -232.0,
 -240.0,
 -248.0,
 -254.4,
 -262.35,
 -270.3,
 -278.25,
 -286.2,
 -294.15,
 -302.1,
 -310.05,
 -316.0,
 -323.9,
 -329.7,
 -337.55,
 -343.2,
 -351.0,
 -358.8,
 -366.6,
 -374.4,
 -382.2,
 -390.0]


y_gross_2 =[90.26,
 82.06,
 92.57,
 84.42,
 76.27,
 68.12,
 59.97,
 51.82,
 43.67,
 35.52,
 27.37,
 19.22,
 11.07,
 45.14,
 37.09,
 29.04,
 20.99,
 12.94,
 21.32,
 13.32,
 5.32,
 -2.68,
 16.32,
 8.37,
 0.42,
 -7.53,
 -15.48,
 -23.43,
 -31.38,
 -39.33,
 -21.95,
 -29.85,
 -3.71,
 -11.56,
 -0.09,
 -7.89,
 -15.69,
 -23.49,
 -31.29,
 -39.09,
 -46.89]

# %%
yyy = [y_profit_2, y_loss_2, y_gross_2]
titles = ["profit", "loss", "gross"]


for i, y in enumerate(yyy):

    plt.scatter(x, y)

    max_value = np.max(y)
    max_index = np.argmax(y)
    max_x_value = x[max_index]

    min_value = np.min(y)
    min_index = np.argmin(y)
    min_x_value = x[min_index]

    plt.title(f"{titles[i]} chart")

    plt.scatter(max_x_value, max_value, color='green')
    plt.text(max_x_value, max_value, f'max = ({max_x_value}, {max_value:.2f})', color='green')

    plt.scatter(min_x_value, min_value, color='red')
    plt.text(min_x_value, min_value, f'min = ({min_x_value}, {min_value:.2f})', color='red')
    plt.show()

# %%
y_profit_3 = [115.45, 115.45, 141.94, 141.94, 141.94, 141.94, 141.94, 141.94, 141.94, 141.94, 141.94, 141.94, 141.94, 198.87, 198.87, 198.87, 198.87, 198.87, 198.87, 198.87, 198.87, 198.87, 241.08, 241.08, 241.08, 241.08, 241.08, 241.08, 241.08, 241.08, 241.08, 241.08, 295.66, 295.66, 320.73, 320.73, 320.73, 320.73, 320.73, 320.73, 320.73]

y_loss_3 = [-84.0, -92.4, -100.2, -108.55, -116.9, -125.25, -133.6, -141.95, -150.3, -158.65, -167.0, -175.35, -183.7, -189.75, -198.0, -206.25, -214.5, -222.75, -231.0, -239.25, -247.5, -255.75, -262.4, -270.6, -278.8, -287.0, -295.2, -303.4, -311.6, -319.8, -328.0, -336.2, -342.3, -350.45, -356.4, -364.5, -372.6, -380.7, -388.8, -396.9, -405.0]

y_gross_3 = [31.45, 23.05, 41.74, 33.39, 25.04, 16.69, 8.34, -0.01, -8.36, -16.71, -25.06, -33.41, -41.76, 9.12, 0.87, -7.38, -15.63, -23.88, -32.13, -40.38, -48.63, -56.88, -21.32, -29.52, -37.72, -45.92, -54.12, -62.32, -70.52, -78.72, -86.92, -95.12, -46.64, -54.79, -35.67, -43.77, -51.87, -59.97, -68.07, -76.17, -84.27]

# %%
yyy = [y_profit_3, y_loss_3, y_gross_3]
titles = ["profit", "loss", "gross"]


for i, y in enumerate(yyy):

    plt.scatter(x, y)

    max_value = np.max(y)
    max_index = np.argmax(y)
    max_x_value = x[max_index]

    min_value = np.min(y)
    min_index = np.argmin(y)
    min_x_value = x[min_index]

    plt.title(f"{titles[i]} chart")

    plt.scatter(max_x_value, max_value, color='green')
    plt.text(max_x_value, max_value, f'max = ({max_x_value}, {max_value:.2f})', color='green')

    plt.scatter(min_x_value, min_value, color='red')
    plt.text(min_x_value, min_value, f'min = ({min_x_value}, {min_value:.2f})', color='red')
    plt.show()

# %%
y_profit_4 = [87.03, 87.03, 125.23, 125.23, 125.23, 125.23, 125.23, 125.23, 125.23, 125.23, 125.23, 125.23, 125.23, 209.15, 209.15, 209.15, 209.15, 209.15, 209.15, 209.15, 209.15, 209.15, 251.36, 251.36, 251.36, 251.36, 251.36, 251.36, 251.36, 251.36, 251.36, 251.36, 305.94, 305.94, 342.77, 342.77, 342.77, 342.77, 342.77, 342.77, 342.77]

y_loss_4 = [-85.0, -93.5, -101.4, -109.85, -118.3, -126.75, -135.2, -143.65, -152.1, -160.55, -169.0, -177.45, -185.9, -192.05, -200.4, -208.75, -217.1, -225.45, -233.8, -242.15, -250.5, -258.85, -265.6, -273.9, -282.2, -290.5, -298.8, -307.1, -315.4, -323.7, -332.0, -340.3, -346.5, -354.75, -360.8, -369.0, -377.2, -385.4, -393.6, -401.8, -410.0]

y_gross_4 = [2.03, -6.47, 23.83, 15.38, 6.93, -1.52, -9.97, -18.42, -26.87, -35.32, -43.77, -52.22, -60.67, 17.1, 8.75, 0.4, -7.95, -16.3, -24.65, -33.0, -41.35, -49.7, -14.24, -22.54, -30.84, -39.14, -47.44, -55.74, -64.04, -72.34, -80.64, -88.94, -40.56, -48.81, -18.03, -26.23, -34.43, -42.63, -50.83, -59.03, -67.23]

# %%
yyy = [y_profit_4, y_loss_4, y_gross_4]
titles = ["profit", "loss", "gross"]


for i, y in enumerate(yyy):

    plt.scatter(x, y)

    max_value = np.max(y)
    max_index = np.argmax(y)
    max_x_value = x[max_index]

    min_value = np.min(y)
    min_index = np.argmin(y)
    min_x_value = x[min_index]

    plt.title(f"{titles[i]} chart")

    plt.scatter(max_x_value, max_value, color='green')
    plt.text(max_x_value, max_value, f'max = ({max_x_value}, {max_value:.2f})', color='green')

    plt.scatter(min_x_value, min_value, color='red')
    plt.text(min_x_value, min_value, f'min = ({min_x_value}, {min_value:.2f})', color='red')
    plt.show()

# %%
import shutil

source_file_path = '.\..\..\.env'

destination_file_path = '.'

shutil.copy(source_file_path, destination_file_path)
# Out:
# '.\\.env'

# %%
import django
import os
import sys
project_path = '../../'  # Adjust this to your actual project path
sys.path.append(project_path)
os.environ.setdefault('DJANGO_SETTINGS_MODULE', 'oogway.settings')
django.setup()
from asgiref.sync import sync_to_async
from PostAnalyzer.models import (
    Predict,
)
import warnings
from Shared.helpers import convertToJsonFile




# Disable all warnings
warnings.filterwarnings("ignore")

# 1000 $
# my_money = 1_000

# %%
# from Strategies.Strategy10.Strategy import backtest_with_money_strategy_10


# predicts: list[Predict] = await sync_to_async(list)(Predict.objects.all().order_by('date').select_related('post', 'status', 'position', 'symbol', 'market'))
# my_money = 150

# history = await backtest_with_money_strategy_10(predicts=predicts, my_money=my_money, close_tp=2, positionSize=100, showPrint=True, max_percent_stoploss=10)

# convertToJsonFile(history, 'history', '.')

# %%
from Strategies.Strategy12 import Strategy10


my_money = 100
strategy10 = Strategy10(money=my_money,timeZone='Asia/Tehran')


predicts: list[Predict] = await sync_to_async(list)(Predict.objects.all().order_by('date').select_related('post', 'status', 'position', 'symbol', 'market'))


await strategy10.backtest_with_money_strategy_10(predicts=predicts, close_tp=3, showPrint=not False, positionSize=25)
strategy10.report()
# strategy10.history

# convertToJsonFile(strategy10.history, 'history', '.')
# Out:
# ETH-USDT, current_money: 100, blocked_money: 0
# money_taken: 25, current_money: 75
# take-profit or stoploss or entry target has no been reach completely, so pending
#
#
#
# SUI-USDT, current_money: 75, blocked_money: 25
# money_taken: 25, current_money: 50
# profit: 32.06, money back: 57.06
# current_money: 107.06
#
#
#
# GRT-USDT, current_money: 107.06, blocked_money: 25
# money_taken: 25, current_money: 82.06
# profit: 27.92, money back: 52.92
# current_money: 134.98
#
#
#
# AAVE-USDT, current_money: 134.98, blocked_money: 25
# money_taken: 25, current_money: 109.98
# take-profit or stoploss or entry target has no been reach completely, so pending
#
#
#
# LINK-USDT, current_money: 109.98, blocked_money: 50
# money_taken: 25, current_money: 84.98
# profit: -0.36, money back: 24.64
# current_money: 109.62
#
#
#
# RUNE-USDT, current_money: 84.98, blocked_money: 50
# money_taken: 25, current_money: 59.98
# profit: -13.8, money back: 11.2
# current_money: 71.18
#
#
#
# BTC-USDT, current_money: 71.18, blocked_money: 50
# money_taken: 25, current_money: 46.18
# profit: -15.7, money back: 9.3
# current_money: 55.47
#
#
#
# ATOM-USDT, current_money: 70.81, blocked_money: 50
# money_taken: 25, current_money: 45.81
# profit: 33.95, money back: 58.95
# current_money: 104.76
#
#
#
# AVAX-USDT, current_money: 55.11, blocked_money: 50
# money_taken: 25, current_money: 30.11
# profit: 36.19, money back: 61.19
# current_money: 91.3
#
#
#
# ETH-USDT, current_money: 89.06, blocked_money: 50
# money_taken: 25, current_money: 64.06
# profit: -15.73, money back: 9.27
# current_money: 73.33
#
#
#
# ETH-USDT, current_money: 64.06, blocked_money: 50
# money_taken: 25, current_money: 39.06
# profit: -18.92, money back: 6.08
# current_money: 45.14
#
#
#
# FTM-USDT, current_money: 39.06, blocked_money: 50
# money_taken: 25, current_money: 14.06
# profit: 30.8, money back: 55.8
# current_money: 69.86
#
#
#
# BNB-USDT, current_money: 69.86, blocked_money: 50
# money_taken: 25, current_money: 44.86
# profit: -18.02, money back: 6.98
# current_money: 51.85
#
#
#
# BTC-USDT, current_money: 44.86, blocked_money: 50
# money_taken: 25, current_money: 19.86
# profit: -19.18, money back: 5.82
# current_money: 25.68
#
#
#
# BTC-USDT, current_money: 19.86, blocked_money: 50
# BTC-USDT missed
#
# SAND-USDT, current_money: 19.86, blocked_money: 50
# SAND-USDT missed
#
# INJ-USDT, current_money: 25.68, blocked_money: 50
# money_taken: 25, current_money: 0.68
# profit: 25.73, money back: 50.73
# current_money: 51.41
#
#
#
# ETH-USDT, current_money: 61.87, blocked_money: 50
# money_taken: 25, current_money: 36.87
# profit: -24.94, money back: 0.06
# current_money: 36.93
#
#
#
# BTC-USDT, current_money: 53.19, blocked_money: 50
# money_taken: 25, current_money: 28.19
# take-profit or stoploss or entry target has no been reach completely, so pending
#
#
#
# APE-USDT, current_money: 34.27, blocked_money: 95.7
# money_taken: 25, current_money: 9.27
# take-profit or stoploss or entry target has no been reach completely, so pending
#
#
#
# ETH-USDT, current_money: 59.99, blocked_money: 126.18
# money_taken: 25, current_money: 34.99
# profit: -9.96, money back: 15.04
# current_money: 50.04
#
#
#
# APT-USDT, current_money: 50.04, blocked_money: 126.18
# money_taken: 25, current_money: 25.04
# take-profit or stoploss or entry target has no been reach completely, so pending
#
#
#
# XRP-USDT, current_money: 25.04, blocked_money: 156.18
# money_taken: 25, current_money: 0.04
# take-profit or stoploss or entry target has no been reach completely, so pending
#
#
#
# BTC-USDT, current_money: 0.04, blocked_money: 181.18
# BTC-USDT missed
#
# BTC-USDT, current_money: 0.04, blocked_money: 181.18
# BTC-USDT missed
#
# BTC-USDT, current_money: 0.04, blocked_money: 181.18
# BTC-USDT missed
# <p style='color:gold;'>initial money: 100</p>
# <p style='color:#1da44f;'>total_opening_orders: 18</p>
# <p style='color:pink;'>total_loss: -136.61076000000003</p>
# <p style='color:green;'>total_profit: 217.83060999999995</p>
# <p style='color:deeppink;'>gross: 81.21984999999992</p>
# <p style='color:grey;'>total_pending: 181.18406</p>
# <p style='color:orange;'>my free money: 0.03578999999999155</p>
# <p style='color:#d16984;'>my total money: 181.21984999999998</p>
# 25 2024-10-24 12:54:57+03:30                       NaT   BTC-USDT   0.00000
#
#      status               status_date  status_type   market position  \
# 0   PENDING                       NaT            0  FUTURES     LONG
# 1    PROFIT 2024-09-08 18:52:00+03:30            4  FUTURES    SHORT
# 2    PROFIT 2024-09-09 01:47:00+03:30            4  FUTURES     LONG
# 3   PENDING                       NaT            0  FUTURES     LONG
# 4      LOSS 2024-09-12 12:07:00+03:30           -1  FUTURES    SHORT
# 5      LOSS 2024-09-10 20:45:00+03:30           -1  FUTURES    SHORT
# 6      LOSS 2024-09-11 20:24:00+03:30           -1  FUTURES    SHORT
# 7    PROFIT 2024-09-13 11:43:00+03:30            4  FUTURES     LONG
# 8    PROFIT 2024-09-18 17:16:00+03:30            4  FUTURES    SHORT
# 9      LOSS 2024-09-19 11:10:00+03:30           -1  FUTURES    SHORT
# 10     LOSS 2024-09-20 07:29:00+03:30           -1  FUTURES    SHORT
# 11   PROFIT 2024-09-17 09:04:00+03:30            4  FUTURES     LONG
# 12     LOSS 2024-09-19 20:16:00+03:30           -1  FUTURES    SHORT
# 13     LOSS 2024-09-18 13:46:00+03:30           -1  FUTURES     LONG
# 14   MISSED                       NaT            0  FUTURES     LONG
# 15   MISSED                       NaT            0  FUTURES     LONG
# 16   PROFIT 2024-09-19 03:26:00+03:30            4  FUTURES     LONG
# 17     LOSS 2024-09-19 20:02:00+03:30           -1  FUTURES    SHORT
# 18   PROFIT 2024-09-20 17:42:00+03:30            3  FUTURES    SHORT
# 19   PROFIT 2024-09-21 05:37:00+03:30            1  FUTURES    SHORT
# 20     LOSS 2024-09-22 02:50:00+03:30           -1  FUTURES    SHORT
# 21   PROFIT 2024-09-22 12:27:00+03:30            1  FUTURES     LONG
# 22  PENDING                       NaT            0  FUTURES     LONG
# 23   MISSED                       NaT            0  FUTURES     LONG
# 24   MISSED                       NaT            0  FUTURES     LONG
# 25   MISSED                       NaT            0  FUTURES     LONG
#
#     leverage    stopLoss     id
# 0          5   2140.4500  12672
# 1          8      0.9930  12673
# 2         12      0.1299  12674
# 3          5    125.0800  12675
# 4          6     10.9600  12676
# 5          5      4.0880  12677
# 6         18  57275.0000  12680
# 7          9      3.9840  12681
# 8          4     26.8740  12682
# 9         20   2439.3000  12683
# 10         4   2515.5000  12685
# 11         6      0.5010  12686
# 12         6    571.1500  12687
# 13        12  59447.1800  12688
# 14        12  59447.1800  12689
# 15         6      0.2384  12690
# 16         4     17.6300  12691
# 17         4   2472.2200  12692
# 18         9  65733.7000  12693
# 19         4      0.8420  12694
# 20        10   2605.1000  12695
# 21         7      7.5760  12696
# 22         9      0.5755  12697
# 23         6  29010.0000  12699
# 24         6  29010.0000  12698
# 25         6  29010.0000  12700
